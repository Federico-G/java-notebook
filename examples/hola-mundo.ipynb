// %% [markdown]
// # Hola Mundo
// Tu primer programa Java en el navegador.

// %%
System.out.println("Hola, Mundo!");

// %% [markdown]
// ## Variables
// Prueba a cambiar el nombre y ejecutar de nuevo.

// %%
String nombre = "Java Notebook";
int anio = 2026;
System.out.println("Bienvenido a " + nombre + " (" + anio + ")");
